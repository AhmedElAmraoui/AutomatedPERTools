# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append("./src")

from utils import *

from qiskit import QuantumCircuit, transpile
from qiskit_aer import Aer, AerSimulator
from qiskit.providers.fake_provider import GenericBackendV2
from qiskit_ibm_runtime.fake_provider import FakeWashingtonV2, FakeAthensV2

from matplotlib import pyplot as plt
import sys
import numpy as np
from qiskit.quantum_info import Pauli, Statevector
from qiskit_aer.noise import NoiseModel, pauli_error
from qiskit.visualization import plot_gate_map
from qiskit.transpiler import CouplingMap

import pickle


sys.path.append("../../pauli_lindblad_per/")
from tomography.experiment import SparsePauliTomographyExperiment as tomography

plt.style.use("ggplot")

# %%
coupling = CouplingMap(couplinglist=[(0, 1), (1, 2), (2, 3)])
backend = GenericBackendV2(num_qubits=4, coupling_map=coupling)

num_qubits, coupling_map = get_backend_info(backend)
plot_gate_map(backend)

hx = 1
hz = 1
J= -1
H_sparse = build_sparse_hamiltonian(hx, hz, backend, J=J)

best_guess, energy_exact = find_best_initial_params(H_sparse, backend)

opt_params, min_error = optimize_energy(best_guess, H_sparse, backend, energy_exact)

expectation_values, paulis = compute_individual_expectation_values(opt_params, backend, hx, hz,J=J, num_layers=1)

print(f"Initial Error: {compute_error(best_guess, H_sparse, backend, energy_exact, num_layers=1)}")
print("Exakte Energie: ", energy_exact)
print("Optimierte Parameter:", opt_params)
print("Minimaler Fehler:", min_error)
# Out:
# Initial Error: 0.10484684299231518
# Exakte Energie:  -7.819890870294844
# Optimierte Parameter: [-3.14159265 -1.57070024  1.57082404]
# Minimaler Fehler: 0.10484684938626751

# %%
backend = FakeWashingtonV2()
plot_gate_map(backend)
"""coupling_list = backend.configuration().coupling_map
print("Coupling Map:", coupling_list)"""

noise_model = NoiseModel.from_backend(backend)
simulator = AerSimulator.from_backend(backend)

# %%
inst_map = [0,1,2,3]
qc = build_hva_layers(opt_params, backend, qubit_indices=inst_map, num_layers=1)

qc.draw('mpl')

# %%
experiment = tomography(
    circuits = [qc], #list of circuits from which to get the layers requiring tomography
    inst_map = inst_map, #which physical qubits on the processor to map the qubits in the circuit
    backend = backend, #quantum backend
    used_qubits= inst_map
    )

experiment.generate(
    samples = 100, #Number of samples to take from the fidelity pair measurements
    single_samples = 250, #samples to take from the pair-breaking measurements
    depths = [2,4,16,32,64] #values of 2n to make the pair measurements. Numbers must be even and non-zero
    )

shots = 1024
def executor(circuits):
    return backend.run(circuits, shots = shots, noise_model=noise_model).result().get_counts()

#run the experiment
experiment.run(executor)
noisedataframe = experiment.analyze()

# %%
"""with open("Experiment.pkl", "rb") as f:
    experiment = pickle.load(f)"""
    
    
with open("Experiment.pkl", "wb") as f:
    pickle.dump(experiment, f)

# %%
layer = experiment.analysis.get_layer_data(0)
layer.plot_infidelitites(plot_style = 2)

# %%
layer.plot_coeffs(plot_style = 2)

# %%
# 2. PER-Experiment Setup
perexp = experiment.create_per_experiment([qc])

perexp.generate(
    expectations=paulis,
    samples=500,
    noise_strengths=[0, 1, 2]
)

# 3. Ausführen
perexp.run(executor)

# %%
# 4. Analysieren
per_results = perexp.analyze()
result_1 = per_results[0].get_result(paulis[0]).plot()
print("Aus SV-Simulation: ",expectation_values[1])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 4. Analysieren
# ----> 2 per_results = perexp.analyze()
#       3 result_1 = per_results[0].get_result(paulis[0]).plot()
#       4 print("Aus SV-Simulation: ",expectation_values[1])
#
# File c:\Users\kchar\OneDrive\Desktop\Uni\Hiwi_Orth\Qiskit\UpdatedCode\per\perexperiment.py:137, in PERExperiment.analyze(self)
#     133 def analyze(self):
#     134
#     135     #run analysis on all instances and return results for each circuit
#     136     for run in self._per_runs:
# --> 137         run.analyze()
#     139     return self._per_runs
#
# File c:\Users\kchar\OneDrive\Desktop\Uni\Hiwi_Orth\Qiskit\UpdatedCode\per\perrun.py:57, in PERRun.analyze(self)
#      54             spam = self._get_spam(basis)
#      55             self._data[basis] = PERData(basis, spam)
# ---> 57         self._data[basis].add_data(inst)
#      59 for perdat in self._data.values():
#      60     perdat.fit()
#
# File c:\Users\kchar\OneDrive\Desktop\Uni\Hiwi_Orth\Qiskit\UpdatedCode\per\perdata.py:31, in PERData.add_data(self, inst)
#      23 """Add data from a PERInstance to the class. Compute the expectation value and store
#      24 as a function of noise strength
#      25
#      26 Args:
#      27     inst (PERInstance): a run of PER
#      28 """
#      30 strength = inst.noise_strength
# ---> 31 expectation = inst.get_adjusted_expectation(self.pauli) #get mitigated, untwirled expectation value
#      33 #TODO: non-local spam approximation
#      34 expectation /= self.spam
#
# File c:\Users\kchar\OneDrive\Desktop\Uni\Hiwi_Orth\Qiskit\UpdatedCode\per\perinstance.py:58, in PERInstance.get_adjusted_expectation(self, pauli)
#      54 def get_adjusted_expectation(self, pauli):
#      55     """Returns the expectation value reported by the parent class, but with the sign
#      56     and overhead from the error mitigation"""
# ---> 58     expec = self.get_expectation(pauli)
#      59     return expec * self.overhead * (-1)**self.sgn_tot
#
# File c:\Users\kchar\OneDrive\Desktop\Uni\Hiwi_Orth\Qiskit\UpdatedCode\framework\instance.py:78, in Instance.get_expectation(self, pauli)
#      76 result = self._untwirl_result()
#      77 #compute locations of non-idetity terms (reversed indexing)
# ---> 78 pz = list(reversed([{pauli_type("I"):'0'}.get(p,'1') for p in pauli]))
#      79 #compute estimator
#      80 for key in result.keys():
#      81     #compute the overlap in the computational basis
#
# File c:\Users\kchar\OneDrive\Desktop\Uni\Hiwi_Orth\Qiskit\UpdatedCode\framework\instance.py:78, in <listcomp>(.0)
#      76 result = self._untwirl_result()
#      77 #compute locations of non-idetity terms (reversed indexing)
# ---> 78 pz = list(reversed([{pauli_type("I"):'0'}.get(p,'1') for p in pauli]))
#      79 #compute estimator
#      80 for key in result.keys():
#      81     #compute the overlap in the computational basis
#
# File c:\Users\kchar\OneDrive\Desktop\Uni\Hiwi_Orth\Qiskit\UpdatedCode\primitives\pauli.py:76, in Pauli.__eq__(self, other)
#      75 def __eq__(self, other): #equality does not record phase if any
# ---> 76     return self.to_label() == other.to_label()
#
# File c:\Users\kchar\OneDrive\Desktop\Uni\Hiwi_Orth\Qiskit\UpdatedCode\primitives\pauli.py:91, in QiskitPauli.to_label(self)
#      90 def to_label(self):
# ---> 91     pauli_nophase = self.Pauli((self.pauli.z, self.pauli.x))
#      92     return pauli_nophase.to_label()
#
# File c:\Users\kchar\OneDrive\Desktop\Uni\Hiwi_Orth\Qiskit\qiskit-venv\lib\site-packages\qiskit\quantum_info\operators\symplectic\pauli.py:188, in Pauli.__init__(self, data)
#     166 def __init__(self, data: str | tuple | Pauli | ScalarOp | QuantumCircuit | None = None):
#     167     r"""Initialize the Pauli.
#     168
#     169     When using the symplectic array input data both z and x arguments must
#    (...)
#     186         QiskitError: if input array is invalid shape.
#     187     """
# --> 188     if isinstance(data, BasePauli):
#     189         base_z, base_x, base_phase = data._z, data._x, data._phase
#     190     elif isinstance(data, tuple):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
for k in range(len(paulis)):
    exact = expectation_values[k]
    calc = per_results[0].get_result(paulis[k]).get_expectations()[0]
    error = abs(abs(exact) - abs(calc)) / abs(exact)

    print(f"Relativer Fehler für {paulis[k]}: {error * 100:.2f}%")

    if error > 0.05:
        print(f"    → Exakter Wert:    {exact}")
        print(f"    → Berechneter Wert: {calc}")
# Out:
# Relativer Fehler für IIZZ: 1.15%
# Relativer Fehler für IZZI: 99.96%
#     → Exakter Wert:    0.8502567619616741
#     → Berechneter Wert: -0.00032308920616973437
# Relativer Fehler für ZZII: 99.86%
#     → Exakter Wert:    0.8502567621551933
#     → Berechneter Wert: -0.001208036674820494
# Relativer Fehler für IIIX: 4.20%
# Relativer Fehler für IIIZ: 0.97%
# Relativer Fehler für IIXI: 4.58%
# Relativer Fehler für IIZI: 5.29%
#     → Exakter Wert:    -0.922093683348159
#     → Berechneter Wert: -0.9708776031462859
# Relativer Fehler für IXII: 160.37%
#     → Exakter Wert:    -0.3869667126164747
#     → Berechneter Wert: 1.0075522119739866
# Relativer Fehler für IZII: 99.98%
#     → Exakter Wert:    -0.9220936833481591
#     → Berechneter Wert: -0.00015477070012107302
# Relativer Fehler für XIII: 167.11%
#     → Exakter Wert:    -0.3869667127045487
#     → Berechneter Wert: 1.0336219275820515
# Relativer Fehler für ZIII: 99.78%
#     → Exakter Wert:    -0.9220936835580283
#     → Berechneter Wert: 0.002035123363273784
